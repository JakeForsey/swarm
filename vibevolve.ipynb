# %%
import json

import altair as alt
import pandas as pd

alt.data_transformers.enable("vegafusion")
# Out:
# DataTransformerRegistry.enable('vegafusion')

# %%
with open("results/vibevolve/rewards.jsonl", "r") as f:
    lines = f.readlines()

df = pd.DataFrame([json.loads(line) for line in lines])
df.head()
# Out:
#      run_id       completion_id     timestamp parent_completion_id    reward  \
# 0  db67855a  1747506993.9613993  1.747507e+09                 None -1.000000
# 1  db67855a  1747506993.9357371  1.747507e+09                 None -0.584375
# 2  db67855a  1747506993.9614189  1.747507e+09                 None -0.053125
# 3  db67855a  1747507016.9986596  1.747507e+09                 None -1.000000
# 4  299e3db9  1747507125.1448984  1.747507e+09                 None -1.000000
#
#                                              results          host
# 0  [{'name': 'simple', 'reward': 1.0}, {'name': '...  cortex1:8080
# 1  [{'name': 'tmp_agent', 'reward': -0.5843750238...  cortex2:8081
# 2  [{'name': 'tmp_agent', 'reward': -0.0531250014...  cortex2:8080
# 3  [{'name': 'simple', 'reward': 1.0}, {'name': '...  cortex1:8080
# 4  [{'name': 'simple', 'reward': 1.0}, {'name': '...  cortex2:8081

# %%
min_timestamp = df.groupby("run_id")["timestamp"].min().to_dict()
data = []
for _, row in df.iterrows():
    for result in row["results"]:
        opponent = "round_robin" if result["name"] == "tmp_agent" else result["name"]
        reward = result["reward"] if result["name"] == "tmp_agent" else -result["reward"]
        error = reward == -1.0
        data.append({
            "opponent": opponent,
            "reward": reward,
            "run_id": row.run_id,
            "timestamp": row.timestamp,
            "seconds": row.timestamp - min_timestamp[row.run_id],
            "error": error,
            "completion_id": row.completion_id,
            "parent_completion_id": row.parent_completion_id,
        })
sub_reward_df = pd.DataFrame(data)
sub_reward_df
# Out:
#            opponent   reward    run_id     timestamp      seconds  error  \
# 0            simple -1.00000  db67855a  1.747507e+09     0.025662   True
# 1      vortex_swarm -1.00000  db67855a  1.747507e+09     0.025662   True
# 2      hunter_swarm -1.00000  db67855a  1.747507e+09     0.025662   True
# 3     predator_boid -1.00000  db67855a  1.747507e+09     0.025662   True
# 4              boid -1.00000  db67855a  1.747507e+09     0.025662   True
# ...             ...      ...       ...           ...          ...    ...
# 1414         chaser  0.87500  299e3db9  1.747510e+09  2646.858746  False
# 1415  concave_swarm  0.65625  299e3db9  1.747510e+09  2646.858746  False
# 1416         center  0.06250  299e3db9  1.747510e+09  2646.858746  False
# 1417          pairs  0.71875  299e3db9  1.747510e+09  2646.858746  False
# 1418         random  0.90625  299e3db9  1.747510e+09  2646.858746  False
#
#            completion_id parent_completion_id
# 0     1747506993.9613993                 None
# 1     1747506993.9613993                 None
# 2     1747506993.9613993                 None
# 3     1747506993.9613993                 None
# 4     1747506993.9613993                 None
# ...                  ...                  ...
# 1414  1747509772.0036442   1747509620.7030475
# 1415  1747509772.0036442   1747509620.7030475
# 1416  1747509772.0036442   1747509620.7030475
# 1417  1747509772.0036442   1747509620.7030475
# 1418  1747509772.0036442   1747509620.7030475
#
# [1419 rows x 8 columns]

# %%
sub_reward_df.sort_values(["run_id", "timestamp"], inplace=True)
sub_reward_df["cummax_reward"] = sub_reward_df.groupby(["opponent"])["reward"].cummax()

x_col = "seconds"
y_col = "reward"
y_col_cummax = "cummax_reward"
tooltip_cols = ["run_id", "completion_id", "reward", "seconds", "completion_id", "parent_completion_id"]

points = alt.Chart(sub_reward_df).encode(
    x=x_col,
    y=y_col,
    color="run_id",
    shape="error",
    tooltip=tooltip_cols,
).mark_circle(
    opacity=0.2,
)

cummax =  alt.Chart(sub_reward_df).encode(
    x=x_col,
    y=y_col_cummax,
    color="run_id",
    tooltip=tooltip_cols,
).mark_line(
    strokeWidth=2,
    color="run_id",
)

figure = (
    (cummax + points)
    .properties(width=175, height=100)
    .facet(
        alt.Facet(
            'opponent',
            sort=alt.EncodingSortField(y_col, op='mean', order='descending')
        ),
        columns=4,
    )
)
figure
# Out:
# alt.FacetChart(...)

# %%
df.iloc[df.reward.argmax()]
# Out:
# run_id                                                           299e3db9
# completion_id                                           1747509034.859665
# timestamp                                               1747509034.859665
# parent_completion_id                                   1747508679.3847902
# reward                                                            0.86875
# results                 [{'name': 'tmp_agent', 'reward': 0.86875003576...
# host                                                         cortex2:8081
# Name: 96, dtype: object

# %%
from swarm.vibevolve import src_from_history
from difflib import unified_diff

def get_parent(run_id, completion_id):
    return df.loc[(df.run_id == run_id) & (df.completion_id == completion_id)].parent_completion_id.values[0]

def get_reward(run_id, completion_id):
    return df.loc[(df.run_id == run_id) & (df.completion_id == completion_id)].reward.values[0]

target_run_id = "299e3db9"
target_completion_id = "1747509034.859665"

parent = get_parent(target_run_id, target_completion_id)
history = [target_completion_id]
while parent is not None:
    parent = get_parent(target_run_id, history[-1])
    history.append(parent)
history.reverse()

for parent_id, child_id in zip(history[:-1], history[1:]):
    if parent_id is not None:
        parent_src = src_from_history(target_run_id, parent_id)
    else:
        parent_src = ""
    child_src = src_from_history(target_run_id, child_id)

    diff_lines = list(unified_diff(parent_src.splitlines(), child_src.splitlines()))
    diff = "\n".join(diff_lines)

    print("-" * 120)
    print(parent_id, "->", child_id)
    print(diff)
# Out:
# ------------------------------------------------------------------------------------------------------------------------
# None -> 1747507161.6284041
# ---
#
# +++
#
# @@ -0,0 +1,56 @@
#
# +
# +import jax
# +import jax.numpy as jnp
# +from jax import jit
# +
# +@jit
# +def act(
# +    t,
# +    key,
# +    ally_x,
# +    ally_y,
# +    ally_vx,
# +    ally_vy,
# +    ally_health,
# +    enemy_x,
# +    enemy_y,
# +    enemy_vx,
# +    enemy_vy,
# +    enemy_health,
# +):
# +    batch_size, num_agents = ally_x.shape
# +
# +    # Normalize positions to be in [-1, 1] for better gradient stability
# +    max_pos = jnp.max(jnp.max(jnp.stack([ally_x, ally_y, enemy_x, enemy_y], axis=0), axis=1))
# +    ally_x = ally_x / max_pos
# +    ally_y = ally_y / max_pos
# +    enemy_x = enemy_x / max_pos
# +    enemy_y = enemy_y / max_pos
# +
# +    # Compute relative positions from each ally to each enemy
# +    relative_x = enemy_x[:, None, :] - ally_x[:, :, None]
# +    relative_y = enemy_y[:, None, :] - ally_y[:, :, None]
# +
# +    # Normalize relative positions
# +    relative_dist = jnp.sqrt(relative_x**2 + relative_y**2)
# +    relative_dist = jnp.clip(relative_dist, 1e-5, 1.0)  # Avoid division by zero
# +
# +    # Compute direction towards enemies
# +    direction_x = relative_x / relative_dist
# +    direction_y = relative_y / relative_dist
# +
# +    # Apply a simple strategy: move towards enemies with some noise
# +    noise_scale = 0.05
# +    noise = jax.random.normal(key, shape=(batch_size, num_agents, num_agents)) * noise_scale
# +    dvx = direction_x + noise
# +    dvy = direction_y + noise
# +
# +    # Normalize velocity to prevent too large steps
# +    dvx = dvx / (jnp.sqrt(dvx**2 + dvy**2) + 1e-5)
# +    dvy = dvy / (jnp.sqrt(dvx**2 + dvy**2) + 1e-5)
# +
# +    # Only use the first enemy for each agent (for simplicity in vectorization)
# +    dvx = dvx[:, :, 0]
# +    dvy = dvy[:, :, 0]
# +
# +    return dvx, dvy
# ------------------------------------------------------------------------------------------------------------------------
# 1747507161.6284041 -> 1747507416.9469156
# ---
#
# +++
#
# @@ -20,37 +20,40 @@
#
#  ):
#      batch_size, num_agents = ally_x.shape
#
# -    # Normalize positions to be in [-1, 1] for better gradient stability
# -    max_pos = jnp.max(jnp.max(jnp.stack([ally_x, ally_y, enemy_x, enemy_y], axis=0), axis=1))
# -    ally_x = ally_x / max_pos
# -    ally_y = ally_y / max_pos
# -    enemy_x = enemy_x / max_pos
# -    enemy_y = enemy_y / max_pos
# +    # Normalize all positions to [-1, 1] for better gradient stability
# +    max_pos = jnp.max(jnp.stack([ally_x, ally_y, enemy_x, enemy_y], axis=0))
# +    ally_x = (ally_x - max_pos / 2) / (max_pos / 2)
# +    ally_y = (ally_y - max_pos / 2) / (max_pos / 2)
# +    enemy_x = (enemy_x - max_pos / 2) / (max_pos / 2)
# +    enemy_y = (enemy_y - max_pos / 2) / (max_pos / 2)
#
#      # Compute relative positions from each ally to each enemy
# -    relative_x = enemy_x[:, None, :] - ally_x[:, :, None]
# -    relative_y = enemy_y[:, None, :] - ally_y[:, :, None]
# +    relative_x = enemy_x[:, None, :] - ally_x[:, :, None]  # [B, A, E]
# +    relative_y = enemy_y[:, None, :] - ally_y[:, :, None]  # [B, A, E]
# +
# +    # Compute distances and filter only nearby enemies
# +    relative_dist = jnp.sqrt(relative_x**2 + relative_y**2)  # [B, A, E]
# +    near_mask = relative_dist < 0.5  # Only consider enemies within 0.5 distance
#
#      # Normalize relative positions
# -    relative_dist = jnp.sqrt(relative_x**2 + relative_y**2)
# -    relative_dist = jnp.clip(relative_dist, 1e-5, 1.0)  # Avoid division by zero
# -
# -    # Compute direction towards enemies
# +    relative_dist = jnp.clip(relative_dist, 1e-5, 1.0)
#      direction_x = relative_x / relative_dist
#      direction_y = relative_y / relative_dist
#
# -    # Apply a simple strategy: move towards enemies with some noise
# +    # Use only the nearest enemy for each agent
# +    nearest_idx = jnp.argmin(relative_dist, axis=2)  # [B, A]
# +    nearest_dir_x = jnp.take_along_axis(direction_x, nearest_idx[:, :, None], axis=2).squeeze(2)  # [B, A]
# +    nearest_dir_y = jnp.take_along_axis(direction_y, nearest_idx[:, :, None], axis=2).squeeze(2)  # [B, A]
# +
# +    # Add noise to the direction
#      noise_scale = 0.05
# -    noise = jax.random.normal(key, shape=(batch_size, num_agents, num_agents)) * noise_scale
# -    dvx = direction_x + noise
# -    dvy = direction_y + noise
# +    noise = jax.random.normal(key, shape=(batch_size, num_agents)) * noise_scale
# +    dvx = nearest_dir_x + noise
# +    dvy = nearest_dir_y + noise
#
#      # Normalize velocity to prevent too large steps
# -    dvx = dvx / (jnp.sqrt(dvx**2 + dvy**2) + 1e-5)
# -    dvy = dvy / (jnp.sqrt(dvx**2 + dvy**2) + 1e-5)
# -
# -    # Only use the first enemy for each agent (for simplicity in vectorization)
# -    dvx = dvx[:, :, 0]
# -    dvy = dvy[:, :, 0]
# +    velocity_magnitude = jnp.sqrt(dvx**2 + dvy**2) + 1e-5
# +    dvx = dvx / velocity_magnitude
# +    dvy = dvy / velocity_magnitude
#
#      return dvx, dvy
# ------------------------------------------------------------------------------------------------------------------------
# 1747507416.9469156 -> 1747507763.1207519
# ---
#
# +++
#
# @@ -20,12 +20,13 @@
#
#  ):
#      batch_size, num_agents = ally_x.shape
#
# -    # Normalize all positions to [-1, 1] for better gradient stability
# +    # Normalize positions to [-1, 1] with a dynamic scale
#      max_pos = jnp.max(jnp.stack([ally_x, ally_y, enemy_x, enemy_y], axis=0))
# -    ally_x = (ally_x - max_pos / 2) / (max_pos / 2)
# -    ally_y = (ally_y - max_pos / 2) / (max_pos / 2)
# -    enemy_x = (enemy_x - max_pos / 2) / (max_pos / 2)
# -    enemy_y = (enemy_y - max_pos / 2) / (max_pos / 2)
# +    scale = max_pos / 2
# +    ally_x = (ally_x - scale) / scale
# +    ally_y = (ally_y - scale) / scale
# +    enemy_x = (enemy_x - scale) / scale
# +    enemy_y = (enemy_y - scale) / scale
#
#      # Compute relative positions from each ally to each enemy
#      relative_x = enemy_x[:, None, :] - ally_x[:, :, None]  # [B, A, E]
# @@ -34,6 +35,7 @@
#
#      # Compute distances and filter only nearby enemies
#      relative_dist = jnp.sqrt(relative_x**2 + relative_y**2)  # [B, A, E]
#      near_mask = relative_dist < 0.5  # Only consider enemies within 0.5 distance
# +    safe_mask = relative_dist > 1.0  # Avoid enemies that are too close
#
#      # Normalize relative positions
#      relative_dist = jnp.clip(relative_dist, 1e-5, 1.0)
# @@ -56,4 +58,15 @@
#
#      dvx = dvx / velocity_magnitude
#      dvy = dvy / velocity_magnitude
#
# +    # Apply velocity smoothing (momentum)
# +    momentum = 0.9
# +    dvx = momentum * ally_vx + (1 - momentum) * dvx
# +    dvy = momentum * ally_vy + (1 - momentum) * dvy
# +
# +    # Prioritize health regeneration if health is below a threshold
# +    health_threshold = 0.5
# +    low_health_mask = ally_health < health_threshold
# +    dvx = jnp.where(low_health_mask, dvx * 0.5, dvx)  # Reduce movement to regenerate
# +    dvy = jnp.where(low_health_mask, dvy * 0.5, dvy)
# +
#      return dvx, dvy
# ------------------------------------------------------------------------------------------------------------------------
# 1747507763.1207519 -> 1747508351.270688
# ---
#
# +++
#
# @@ -23,14 +23,14 @@
#
#      # Normalize positions to [-1, 1] with a dynamic scale
#      max_pos = jnp.max(jnp.stack([ally_x, ally_y, enemy_x, enemy_y], axis=0))
#      scale = max_pos / 2
# -    ally_x = (ally_x - scale) / scale
# -    ally_y = (ally_y - scale) / scale
# -    enemy_x = (enemy_x - scale) / scale
# -    enemy_y = (enemy_y - scale) / scale
# +    ally_x_norm = (ally_x - scale) / scale
# +    ally_y_norm = (ally_y - scale) / scale
# +    enemy_x_norm = (enemy_x - scale) / scale
# +    enemy_y_norm = (enemy_y - scale) / scale
#
#      # Compute relative positions from each ally to each enemy
# -    relative_x = enemy_x[:, None, :] - ally_x[:, :, None]  # [B, A, E]
# -    relative_y = enemy_y[:, None, :] - ally_y[:, :, None]  # [B, A, E]
# +    relative_x = enemy_x_norm[:, None, :] - ally_x_norm[:, :, None]  # [B, A, E]
# +    relative_y = enemy_y_norm[:, None, :] - ally_y_norm[:, :, None]  # [B, A, E]
#
#      # Compute distances and filter only nearby enemies
#      relative_dist = jnp.sqrt(relative_x**2 + relative_y**2)  # [B, A, E]
# @@ -47,11 +47,22 @@
#
#      nearest_dir_x = jnp.take_along_axis(direction_x, nearest_idx[:, :, None], axis=2).squeeze(2)  # [B, A]
#      nearest_dir_y = jnp.take_along_axis(direction_y, nearest_idx[:, :, None], axis=2).squeeze(2)  # [B, A]
#
# +    # Avoid enemies that are too close (repulsion)
# +    repulsion_radius = 0.3
# +    repulsion_strength = 2.0
# +    repulsion_mask = relative_dist < repulsion_radius
# +    repulsion_x = jnp.where(repulsion_mask, -relative_x * repulsion_strength / (relative_dist**2), 0)
# +    repulsion_y = jnp.where(repulsion_mask, -relative_y * repulsion_strength / (relative_dist**2), 0)
# +
# +    # Combine repulsion with attraction to nearest enemy
# +    combined_dir_x = nearest_dir_x + jnp.mean(repulsion_x, axis=2)  # Average repulsion over all enemies
# +    combined_dir_y = nearest_dir_y + jnp.mean(repulsion_y, axis=2)
# +
#      # Add noise to the direction
#      noise_scale = 0.05
#      noise = jax.random.normal(key, shape=(batch_size, num_agents)) * noise_scale
# -    dvx = nearest_dir_x + noise
# -    dvy = nearest_dir_y + noise
# +    dvx = combined_dir_x + noise
# +    dvy = combined_dir_y + noise
#
#      # Normalize velocity to prevent too large steps
#      velocity_magnitude = jnp.sqrt(dvx**2 + dvy**2) + 1e-5
# ------------------------------------------------------------------------------------------------------------------------
# 1747508351.270688 -> 1747508613.7406523
#
# ------------------------------------------------------------------------------------------------------------------------
# 1747508613.7406523 -> 1747508679.3847902
# ---
#
# +++
#
# @@ -35,7 +35,6 @@
#
#      # Compute distances and filter only nearby enemies
#      relative_dist = jnp.sqrt(relative_x**2 + relative_y**2)  # [B, A, E]
#      near_mask = relative_dist < 0.5  # Only consider enemies within 0.5 distance
# -    safe_mask = relative_dist > 1.0  # Avoid enemies that are too close
#
#      # Normalize relative positions
#      relative_dist = jnp.clip(relative_dist, 1e-5, 1.0)
# @@ -47,7 +46,7 @@
#
#      nearest_dir_x = jnp.take_along_axis(direction_x, nearest_idx[:, :, None], axis=2).squeeze(2)  # [B, A]
#      nearest_dir_y = jnp.take_along_axis(direction_y, nearest_idx[:, :, None], axis=2).squeeze(2)  # [B, A]
#
# -    # Avoid enemies that are too close (repulsion)
# +    # Collision avoidance (repulsion from enemies)
#      repulsion_radius = 0.3
#      repulsion_strength = 2.0
#      repulsion_mask = relative_dist < repulsion_radius
# @@ -58,7 +57,7 @@
#
#      combined_dir_x = nearest_dir_x + jnp.mean(repulsion_x, axis=2)  # Average repulsion over all enemies
#      combined_dir_y = nearest_dir_y + jnp.mean(repulsion_y, axis=2)
#
# -    # Add noise to the direction
# +    # Add noise to the direction for exploration
#      noise_scale = 0.05
#      noise = jax.random.normal(key, shape=(batch_size, num_agents)) * noise_scale
#      dvx = combined_dir_x + noise
# ------------------------------------------------------------------------------------------------------------------------
# 1747508679.3847902 -> 1747509034.859665
# ---
#
# +++
#
# @@ -20,9 +20,9 @@
#
#  ):
#      batch_size, num_agents = ally_x.shape
#
# -    # Normalize positions to [-1, 1] with a dynamic scale
# +    # Normalize all positions to [-1, 1] based on the max of all agents
#      max_pos = jnp.max(jnp.stack([ally_x, ally_y, enemy_x, enemy_y], axis=0))
# -    scale = max_pos / 2
# +    scale = max_pos / 2.0
#      ally_x_norm = (ally_x - scale) / scale
#      ally_y_norm = (ally_y - scale) / scale
#      enemy_x_norm = (enemy_x - scale) / scale
# @@ -47,7 +47,7 @@
#
#      nearest_dir_y = jnp.take_along_axis(direction_y, nearest_idx[:, :, None], axis=2).squeeze(2)  # [B, A]
#
#      # Collision avoidance (repulsion from enemies)
# -    repulsion_radius = 0.3
# +    repulsion_radius = 0.2
#      repulsion_strength = 2.0
#      repulsion_mask = relative_dist < repulsion_radius
#      repulsion_x = jnp.where(repulsion_mask, -relative_x * repulsion_strength / (relative_dist**2), 0)
# @@ -58,7 +58,7 @@
#
#      combined_dir_y = nearest_dir_y + jnp.mean(repulsion_y, axis=2)
#
#      # Add noise to the direction for exploration
# -    noise_scale = 0.05
# +    noise_scale = 0.02
#      noise = jax.random.normal(key, shape=(batch_size, num_agents)) * noise_scale
#      dvx = combined_dir_x + noise
#      dvy = combined_dir_y + noise
# @@ -73,10 +73,16 @@
#
#      dvx = momentum * ally_vx + (1 - momentum) * dvx
#      dvy = momentum * ally_vy + (1 - momentum) * dvy
#
# -    # Prioritize health regeneration if health is below a threshold
# +    # Health management
#      health_threshold = 0.5
#      low_health_mask = ally_health < health_threshold
# -    dvx = jnp.where(low_health_mask, dvx * 0.5, dvx)  # Reduce movement to regenerate
# -    dvy = jnp.where(low_health_mask, dvy * 0.5, dvy)
# +    dvx = jnp.where(low_health_mask, dvx * 0.3, dvx)  # Reduce movement to regenerate
# +    dvy = jnp.where(low_health_mask, dvy * 0.3, dvy)
# +
# +    # Add a small random drift to break symmetry and encourage exploration
# +    drift_strength = 0.01
# +    drift = jax.random.normal(key, shape=(batch_size, num_agents)) * drift_strength
# +    dvx = dvx + drift
# +    dvy = dvy + drift
#
#      return dvx, dvy
